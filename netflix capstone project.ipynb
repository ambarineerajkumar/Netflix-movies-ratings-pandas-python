# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
#  # Q1: How can you load a Netflix dataset into a Pandas Data Frame, and what method will you
#  # use to get basic information about the dataset?

# %%
  # Update with your actual file path
df = pd.read_csv('netflix.csv')

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre  \
# 0     Crime, Drama, Fantasy, Horror, Romance
# 1                                     Comedy
# 2                            Comedy, Romance
# 3                                      Drama
# 4                                      Drama
# ...                                      ...
# 9420                Comedy, Fantasy, Romance
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Tags                   9389 non-null   object
#  3   Languages              9255 non-null   object
#  4   Series or Movie        9425 non-null   object
#  5   Hidden Gem Score       9415 non-null   float64
#  6   Country Availability   9414 non-null   object
#  7   Runtime                9424 non-null   object
#  8   Director               7120 non-null   object
#  9   Writer                 7615 non-null   object
#  10  Actors                 9314 non-null   object
#  11  View Rating            6827 non-null   object
#  12  IMDb Score             9417 non-null   float64
#  13  Rotten Tomatoes Score  5445 non-null   float64
# ...

# %% [markdown]
#  # Q2: What Pandas method helps you identify missing values in the dataset, and how can you¶
#  # count the number of missing values for each column?

# %%
 df.isnull().sum()
# Out:
# Title                       0
# Genre                      25
# Tags                       36
# Languages                 170
# Series or Movie             0
# Hidden Gem Score           10
# Country Availability       11
# Runtime                     1
# Director                 2305
# Writer                   1810
# Actors                    111
# View Rating              2598
# IMDb Score                  8
# Rotten Tomatoes Score    3980
# Metacritic Score         5343
# Awards Received          4199
# Awards Nominated For     3049
# Boxoffice                5671
# Release Date              208
# Netflix Release Date        0
# Production House         5032
# Netflix Link                0
# IMDb Link                 324
# Summary                     5
# IMDb Votes                 10
# Image                       0
# Poster                    938
# TMDb Trailer                0
# Trailer Site                1
# dtype: int64

# %% [markdown]
#  # Q3: To get summary statistics for numerical columns, what Pandas method should you use
#  # and what insights can you gather from these statistics?

# %%
df.describe()
# Out:
#        Hidden Gem Score   IMDb Score  Rotten Tomatoes Score  Metacritic Score  \
# count       9415.000000  9417.000000            5445.000000       4082.000000
# mean           5.540733     6.955517              64.691276         58.113425
# std            2.447462     0.899681              25.269466         17.143187
# min            0.600000     1.600000               0.000000          6.000000
# 25%            3.400000     6.500000              49.000000         46.000000
# 50%            5.300000     7.000000              70.000000         59.000000
# 75%            8.100000     7.500000              85.000000         71.000000
# max            9.800000     9.700000             100.000000        100.000000
#
#        Awards Received  Awards Nominated For    IMDb Votes
# count      5226.000000           6376.000000  9.415000e+03
# mean          9.735936             16.035602  6.014725e+04
# std          19.524116             32.209094  1.463837e+05
# ...

# %% [markdown]
#  # Q4: Identify categorical columns using a specific Pandas function, and explain the purpose
#  # of the loop iterating through these columns.

# %%
categorical_cols = df.select_dtypes(include=['object']).columns

# %%
for col in categorical_cols:
    print(f"\nUnique values in {col}:\n", df[col].unique())
# Out:
# Unique values in Title:
#  ['Lets Fight Ghost' 'HOW TO BUILD A GIRL' 'The Con-Heartist' ...
#  'Brand New Day' 'Daniel Arends: Blessuretijd'
#  'DreamWorks Happy Holidays from Madagascar']
#
# Unique values in Genre:
#  ['Crime, Drama, Fantasy, Horror, Romance' 'Comedy' 'Comedy, Romance' ...
#  'Action, Animation, Comedy, Romance'
#  'Animation, Action, Adventure, Fantasy, Sport, Thriller'
#  'Adventure, Drama, Fantasy, Romance, Thriller']
#
# Unique values in Tags:
#  ['Comedy Programmes,Romantic TV Comedies,Horror Programmes,Thai TV Programmes'
#  'Dramas,Comedies,Films Based on Books,British'
#  'Romantic Comedies,Comedies,Romantic Films,Thai Comedies,Thai Films' ...
#  'Social & Cultural Documentaries,Biographical Documentaries,Documentaries,Science & Nature Documentaries,Documentaries'
#  'Australian Comedies,Romantic Comedies,Australian Films,Comedies,Romantic Films'
#  'TV Comedies,Kids TV,Animal Tales,TV Cartoons,TV Programmes,Romantic Favorites,Family Watch Together TV']
#
# ...

# %% [markdown]
# # Q5: Create any plot to visualize the distribution of your choice . Which Seaborn function will
#  # you use, and what information can you obtain from the plot

# %%
plt.figure(figsize=(20,8))
target_col = "View Rating"  
sns.countplot(x=df[target_col])
plt.title("Distribution of View Ratings")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  # Q6: Visualize the distribution of the 'Runtime' column using a Seaborn plot with specific¶
#  # parameters. What insights can you gather from this visualization?

# %%
# Visualizing the distribution of 'Runtime'
sns.histplot(df['Runtime'], bins=30, kde=True)
plt.title("Distribution of Runtime")
plt.xlabel("Runtime (minutes)")
plt.show()

# %% [markdown]
# # Q7: Create any plot of choice to explore the relationship between two numerical columns.
#  # Which Seaborn function should you use, and what does the scatter plot reveal?

# %%
# Scatter plot between IMDb Score and Runtime
sns.scatterplot(x=df['IMDb Score'], y=df['Runtime'])
plt.title("IMDb Score vs. Runtime")
plt.xlabel("IMDb Score")
plt.ylabel("Runtime (minutes)")
plt.show()

# %% [markdown]
#  #   Q8: Introduce a different type of visualization to gain more insights. What Seaborn or¶
#  # Matplotlib function allows you to create this visualization?

# %%
# Additional visualization (Box Plot for IMDb Scores)
sns.boxplot(y=df['IMDb Score'])
plt.title("Box Plot of IMDb Scores")
plt.show()

# %% [markdown]
#  # Q9: How can you display the generated plots? Which Matplotlib function will you use to  showcase these visualizations?
#
#   # Hint: Use plt.show() after creating each plot to display them.

# %%
sns.scatterplot(x=df['IMDb Score'], y=df['Runtime'])
plt.title("IMDb Score vs. Runtime")
plt.xlabel("IMDb Score")
plt.ylabel("Runtime (minutes)")
plt.show()
# Out:
# Observations:
# - The dataset contains missing values in some columns.
# - Runtime distribution appears right-skewed, meaning most movies/shows have shorter durations.
# - IMDb Score and Runtime do not show a strong correlation visually.

# %% [markdown]
# # Q10: Based on the visualizations, what conclusions or recommendations can you make about the Netflix dataset? Consider patterns, trends, or interesting observations
#
#  # Hint: Look for patterns or interesting observations in the visualizations. Consider how different variables relate to each other and what insights can be drawn.

# %% [markdown]
# Answer Genre Popularity   :    Visualizations likely showed that genres such as Drama, Comedy, and Crime are the most popular, whichaligns with general audience preferences. Recommendation: Netflix should continue investing in these highdemand genres while also experimenting with niche genres to cater to specific audience segments, enhancingviewer satisfaction across diverse demographics. Relationship Between IMDb Scores and User Ratings: Scatter plots may reveal a positive correlation between IMDb scores and user ratings, indicating that higherrated content on IMDb also tends to perform well with Netflix audiences. Recommendation: Netflix canconsider IMDb ratings as a valuable predictor of content success and prioritize high-rated IMDb titles foracquisition or recommendation.
